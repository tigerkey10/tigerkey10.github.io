# %%
# 연습문제 4.4.2
black = {'facecolor' : 'black'}

def g(x, y) : 
    return (4*x+6*y-26, 6*x+14*y-54)

g1 = g(7, 1)
g2 = g(2, 1)

plt.plot(0,0,'kp', ms=10) # 좌표평면 0,0 원점에 점 찍는다. 크기는 10
plt.plot(g1[0], g1[1], 'ro', ms=10) #g1 벡터 좌표로 점 찍는다. 
plt.annotate('', xy=g1, xytext=(0,0), arrowprops=black)
plt.plot(g2[0], g2[1],'ro', ms=10)
plt.annotate('', xy=g2, xytext=(0,0), arrowprops=black)

plt.axis('equal')
plt.show()

# %%
a1 = np.array([1/np.sqrt(2), 1/np.sqrt(2)])

# %%
np.linalg.norm(a1)
# Out:
# 0.9999999999999999

# %%
a2 = np.array([1,0])

# %%
np.linalg.norm(a2)
# Out:
# 1.0

# %%
a3 = np.array([1,1])

# %%
a3@a1
# Out:
# 1.414213562373095

# %%
a3@a2
# Out:
# 1
