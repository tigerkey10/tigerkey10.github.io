# %%
import librosa
import librosa.display
import os

# %%
os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/1월 15일/등산')

# %%
audio_path = '/Users/kibeomkim/Desktop/사운드들/test2.wav'
y1, sr = librosa.load(audio_path)
plt.plot(y1)

# %%
folder_list = ['1월 15일', '1월 16일', '1월 18일', '1월 20일', '1월 22일', '1월 25일', '1월 27일', '1월 28일', '1월 29일', '2월 8일', '3월 25일', '6월 21일', '6월 22일', '6월 23일']
jan15 = ['등산.wav', '보다찍다모든순간경이롭게.wav', '유재석펭수언박싱.wav', '집콕파티.wav', '탄생,갤럭시울트라.wav', '한몸에받다세상의시선.wav']
jan16 = ['음식만들기.wav', '포토카드2_풀버전.wav', '포토카드1.wav', '포토카드2.wav']
jan18 = ['이날치릴보이언박싱.wav']
jan20 = ['이날치릴보이.wav']
jan22 = ['s에.wav', '나제일완벽.wav', '내꿈에진심.wav', '비컷없음.wav', '추억100.wav', '통화에서동화.wav']
jan25 = ['디자이너김리을.wav']
jan27 = ['아티스트방.wav']
jan28 = ['손석구.wav']
jan29 = ['팬텀바이올렛.wav']
feb8 = ['손석구코멘터리.wav']
mar25 = ['이제맘놓고보내.wav', '지워봐.wav']
june21 = ['8k비디오편.wav', '인물모드편.wav', '야간모드편.wav']
june22 = ['하나의폰캐스팅더블.wav']
june23 = ['에픽인에브리웨이.wav']

total_list = jan15+jan16+jan18+jan20+jan22+jan25+jan27+jan28+jan29+feb8+mar25+june21+june22+june23

for a in folder_list : 
    if a == '1월 15일' : 
        for b in jan15 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '1월 16일' : 
        for b in jan16 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '1월 18일' : 
        for b in jan18 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '1월 20일' : 
        for b in jan20 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()
    
    if a == '1월 22일' : 
        for b in jan22 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '1월 25일' : 
        for b in jan25 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '1월 27일' : 
        for b in jan27 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '1월 28일' : 
        for b in jan28 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '1월 29일' : 
        for b in jan29 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '2월 8일' : 
        for b in feb8 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '3월 25일' : 
        for b in mar25 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '6월 21일' : 
        for b in june21 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '6월 22일' : 
        for b in june22 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()

    if a == '6월 23일' : 
        for b in june23 : 
            name = b.replace('.wav', '')
            os.makedirs(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')
            os.chdir(f'/Users/kibeomkim/Desktop/사운드들/{a}/{name}')

            audio_path = f'/Users/kibeomkim/Desktop/사운드들/{a}/{b}'
            
            # 사운드 전체 파형 
            y1, sr = librosa.load(audio_path)
            plt.plot(y1)
            plt.savefig(f'{name}.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 피리오도그램 
            import scipy.signal
            f, P  = sp.signal.periodogram(y1, 44100, nfft=2**12)

            plt.subplot(211)
            plt.plot(f, P)
            plt.xlim(100, 1900)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("선형 스케일")

            plt.subplot(212)
            plt.semilogy(f, P)
            plt.xlim(100, 1900)
            plt.ylim(1e-10, 1e-1)
            plt.xlabel('Hz')
            plt.ylabel('freq')
            plt.title("로그 스케일")

            plt.tight_layout()
            plt.savefig(f'periodogram.jpg', dpi=300)
            plt.pause(1)
            plt.close()

            # 스펙트럼 이미지 
            import librosa
            import librosa.display

            D = np.abs(librosa.stft(y1))
            librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='linear', x_axis='time')

            plt.ylim(0, 4000)
            plt.savefig(f'스펙트럼.jpg', dpi=300)
            plt.pause(1)
            plt.close()
