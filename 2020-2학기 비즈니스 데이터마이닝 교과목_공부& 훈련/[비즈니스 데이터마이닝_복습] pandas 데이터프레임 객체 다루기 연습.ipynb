# %%
import pandas as pd
retail = pd.read_csv('c:/bd092_data/NewOnlineRetail.csv')
type(retail)
retail
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 63670   C541589    79323W                  WHITE CHERRY LIGHTS        -8
# 63671    541590     84580          MOUSE TOY WITH PINK T-SHIRT         4
# 63672    541590     22295            HEART FILIGREE DOVE LARGE        12
# 63673    541590    85231B           CINAMMON SET OF 9 T-LIGHTS        12
# 63674    541590     21613     S/12 VANILLA  BOTANICAL T-LIGHTS         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
retail.shape
# Out:
# (63675, 8)

# %%
retail.index
# Out:
# RangeIndex(start=0, stop=63675, step=1)

# %%
retail.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
retail.head(n=35)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
retail.tail(n=20)
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 63655    541588     84378       SET OF 3 HEART COOKIE CUTTERS        12
# 63656    541588     22417      PACK OF 60 SPACEBOY CAKE CASES        24
# 63657    541588     22956            36 FOIL HEART CAKE CASES         6
# 63658    541588     21155               RED RETROSPOT PEG BAG         6
# 63659    541588     22558     CLOTHES PEGS RETROSPOT PACK 24         12
# 63660    541588     22617          BAKING SET SPACEBOY DESIGN         3
# 63661    541588     22138       BAKING SET 9 PIECE RETROSPOT          3
# 63662    541588     21947           SET OF 6 HEART CHOPSTICKS        12
# 63663    541588     22821         GIFT BAG PSYCHEDELIC APPLES        12
# 63664    541588     10135        COLOURING PENCILS BROWN TUBE        10
# 63665    541588     22418              10 COLOUR SPACEBOY PEN        24
# 63666    541588     22045                  SPACEBOY GIFT WRAP        25
# ...

# %%
retail[['InvoiceNo', 'Country']]
# Out:
#       InvoiceNo         Country
# 0        536365  United Kingdom
# 1        536365  United Kingdom
# 2        536365  United Kingdom
# 3        536365  United Kingdom
# 4        536365  United Kingdom
# ...         ...             ...
# 63670   C541589  United Kingdom
# 63671    541590  United Kingdom
# 63672    541590  United Kingdom
# 63673    541590  United Kingdom
# 63674    541590  United Kingdom
#
# [63675 rows x 2 columns]

# %%
import pandas as pd
retail = pd.read_csv('c://bd092_data//NewOnlineRetail.csv')
retail[['0' , 'StockCode','InvoiceNo']]
# Out:
#          0 StockCode InvoiceNo
# 0        f    85123A    536365
# 1       dc     71053    536365
# 2       dd    84406B    536365
# 3      NaN    84029G    536365
# 4      NaN    84029E    536365
# ...    ...       ...       ...
# 63670  NaN    79323W   C541589
# 63671  NaN     84580    541590
# 63672  NaN     22295    541590
# 63673  NaN    85231B    541590
# 63674  NaN     21613    541590
#
# [63675 rows x 3 columns]

# %%
retail.loc[[3:8]] #슬라이싱 할 때는 [] 만으로 가능하다.
# Out:
#   File "<ipython-input-85-090b78025885>", line 1
#     retail.loc[[3:8]] #슬라이싱 할 때는 [] 만으로 가능하다.
#                  ^
# SyntaxError: invalid syntax

# %%
retail.loc[3:8] #예
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom  NaN
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom  NaN
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom  NaN
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom  NaN

# %%
retail.loc[3]#row 선택 할 때는 [] 는 시리즈로 출력, [[]]는 데이터프레임으로 출력이다.
retail.loc[[3]]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN

# %%
retail.loc[3:9] #3번째~9번째 row 그대로 출력
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom  NaN
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom  NaN
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom  NaN
# ...

# %%
retail.iloc[3:9] #마지막꺼에서 -1 하고 출력
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom  NaN
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom  NaN
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom  NaN
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom  NaN

# %%
#row 출력인데 column정보 더해주는 법
retail.loc[3:5, ['InvoiceNo','StockCode','Country']]
# Out:
#   InvoiceNo StockCode         Country
# 3    536365    84029G  United Kingdom
# 4    536365    84029E  United Kingdom
# 5    536365     22752  United Kingdom

# %%
##retail.iloc[55:67,['InvoiceNo', 'Country', '0']]
retail.iloc[53:56]
#iloc는 일반 파이썬 인덱스 
#인덱싱 & 슬라이싱은 별개
#loc가 기본, 인덱싱 하다 0부터 순서 적용할 일 있으면 앞에 i 붙이기 <-- iloc는 인덱싱 순서 변형해주는 것이다.
# Out:
#    InvoiceNo StockCode                     Description  Quantity  \
# 53    536373     37370      RETRO COFFEE MUGS ASSORTED         6
# 54    536373     21871             SAVE THE PLANET MUG         6
# 55    536373     21071  VINTAGE BILLBOARD DRINK ME MUG         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country    0
# 53  12/1/2010 9:02       1.06     17850.0  United Kingdom  NaN
# 54  12/1/2010 9:02       1.06     17850.0  United Kingdom  NaN
# 55  12/1/2010 9:02       1.06     17850.0  United Kingdom  NaN

# %%
retail.iloc[53:56]
# Out:
#    InvoiceNo StockCode                     Description  Quantity  \
# 53    536373     37370      RETRO COFFEE MUGS ASSORTED         6
# 54    536373     21871             SAVE THE PLANET MUG         6
# 55    536373     21071  VINTAGE BILLBOARD DRINK ME MUG         6
#
#        InvoiceDate  UnitPrice  CustomerID         Country    0
# 53  12/1/2010 9:02       1.06     17850.0  United Kingdom  NaN
# 54  12/1/2010 9:02       1.06     17850.0  United Kingdom  NaN
# 55  12/1/2010 9:02       1.06     17850.0  United Kingdom  NaN

# %%
retail.loc[3:55, ['Description', 'Quantity']]
# Out:
#                             Description  Quantity
# 3   KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        RED WOOLLY HOTTIE WHITE HEART.         6
# 5          SET 7 BABUSHKA NESTING BOXES         2
# 6     GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7                HAND WARMER UNION JACK         6
# 8             HAND WARMER RED POLKA DOT         6
# 9         ASSORTED COLOUR BIRD ORNAMENT        32
# 10           POPPY'S PLAYHOUSE BEDROOM          6
# 11            POPPY'S PLAYHOUSE KITCHEN         6
# 12    FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 13              IVORY KNITTED MUG COSY          6
# 14   BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 15        BOX OF VINTAGE JIGSAW BLOCKS          3
# 16       BOX OF VINTAGE ALPHABET BLOCKS         2
# 17             HOME BUILDING BLOCK WORD         3
# 18             LOVE BUILDING BLOCK WORD         3
# 19          RECIPE BOX WITH METAL HEART         4
# 20                  DOORMAT NEW ENGLAND         4
# ...

# %%
#row 호출 : index 이름으로 하면 된다
retail.iloc[[3]]
#정리 : 
#loc 이 기본
#iloc는 loc 인덱싱 순서 바꿔주는 것.
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN

# %%
retail.loc[3:5, ['InvoiceNo']]
# Out:
#   InvoiceNo
# 3    536365
# 4    536365
# 5    536365

# %%
#슬라이싱--> 바로 데이터프레임으로 바꿔준다
#iloc은 인덱싱 순서 잡아주는 놈이라, 단순 인덱싱 때만 쓸 수 있다. 
#인덱싱과 슬라이싱 다르게 쓴다
#[]은 시리즈, [[]]은 데이터프레임으로 출력한다
retail.loc[3:8]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom  NaN
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom  NaN
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom  NaN
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom  NaN

# %%
retail.loc[3]
retail.loc[[3]]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN

# %%
retail.iloc[[3]]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN

# %%
retail.iloc[5:8]
# Out:
#   InvoiceNo StockCode                        Description  Quantity  \
# 5    536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730  GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633             HAND WARMER UNION JACK         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom  NaN
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom  NaN
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom  NaN

# %%
retail.iloc[[3]]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    0
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  NaN

# %%
retail.loc[3, ['InvoiceNo','StockCode']]
# Out:
# InvoiceNo    536365
# StockCode    84029G
# Name: 3, dtype: object

# %%
#슬라이싱해서 복합데이터 데이터프레임으로 출력하기
#복합데이터 데이터프레임 출력은 슬라이싱에서만 가능하다.
retail.loc[3:5, ['InvoiceNo']]
retail.loc[3, ['InvoiceNo']]
#복합데이터 시리즈 출력은 어떤형태로도 가능하다.
# Out:
# InvoiceNo    536365
# Name: 3, dtype: object

# %%
#마지막 정리 
#loc이 기본이고, []는 시리즈 출력, [[]]는 데이터프레임으로 출력해준다
#iloc은 인덱싱 순서 바꿔주는 놈이기 때문에, 단순 인덱싱에만 사용가능하다.<-- 복합 활용 안됨
#row출력은 loc 함수 + row 인덱스 이름 으로 출력한다.
#column 출력은 [] 또는 [[]] 으로 출력한다.
#복합데이터 데이터프레임 형태 출력은 슬라이싱에서만 가능하다.
#슬라이싱은 원래 하듯이 [] 쓰면 데이터프레임 출력 가능하다

# %%
retail.loc[3:89, ['InvoiceNo','Country']].tail(n=23)
# Out:
#    InvoiceNo         Country
# 67    536375  United Kingdom
# 68    536375  United Kingdom
# 69    536375  United Kingdom
# 70    536375  United Kingdom
# 71    536375  United Kingdom
# 72    536375  United Kingdom
# 73    536375  United Kingdom
# 74    536375  United Kingdom
# 75    536375  United Kingdom
# 76    536375  United Kingdom
# 77    536375  United Kingdom
# 78    536375  United Kingdom
# 79    536375  United Kingdom
# 80    536375  United Kingdom
# 81    536375  United Kingdom
# 82    536376  United Kingdom
# 83    536376  United Kingdom
# 84    536377  United Kingdom
# 85    536377  United Kingdom
# 86    536378  United Kingdom
# 87    536378  United Kingdom
# 88    536378  United Kingdom
# 89    536378  United Kingdom
