# %%
import pandas as pd
import numpy as np

# %%
retail = pd.read_csv('c://bd092_data//NewOnlineRetail.csv')

# %%
#슬라이싱은 row 선택에만 이용된다 & 슬라이싱은 하던대로 하면 알아서 데이터프레임 출력된다
retail[100:172]
#
retail.loc[100:172, ['InvoiceNo']]
retail.iloc[[0,33,55], [0,3,5]]
# Out:
#    InvoiceNo  Quantity  UnitPrice
# 0     536365         6       2.55
# 33    536370        18       2.95
# 55    536373         6       1.06

# %%
retail.loc[150:182, ['Unitprice', 'InvoiceNo', 'Quantity']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-25150a7ec6c1> in <module>
# ----> 1 retail.loc[150:182, ['Unitprice', 'InvoiceNo', 'Quantity']]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1287                 continue
#    1288
# -> 1289             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1290
#    1291         return retval
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
1retail
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 63670   C541589    79323W                  WHITE CHERRY LIGHTS        -8
# 63671    541590     84580          MOUSE TOY WITH PINK T-SHIRT         4
# 63672    541590     22295            HEART FILIGREE DOVE LARGE        12
# 63673    541590    85231B           CINAMMON SET OF 9 T-LIGHTS        12
# 63674    541590     21613     S/12 VANILLA  BOTANICAL T-LIGHTS         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country    0
# ...

# %%
cat = retail.loc[150:250, ['Quantity', 'InvoiceNo', 'StockCode']]
cat.isnull().sum()
# Out:
# Quantity     0
# InvoiceNo    0
# StockCode    0
# dtype: int64

# %%
retail = retail[(retail['Quantity']>=10) & (retail['UnitPrice']<=9)]
retail
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 9        536367     84879       ASSORTED COLOUR BIRD ORNAMENT        32
# 26       536370     22728           ALARM CLOCK BAKELIKE PINK        24
# 27       536370     22727           ALARM CLOCK BAKELIKE RED         24
# 28       536370     22726          ALARM CLOCK BAKELIKE GREEN        12
# 29       536370     21724     PANDA AND BUNNIES STICKER SHEET        12
# ...         ...       ...                                 ...       ...
# 63667    541588     22435      SET OF 9 HEART SHAPED BALLOONS        12
# 63668    541588     21210  SET OF 72 RETROSPOT PAPER  DOILIES        12
# 63669    541588     21212     PACK OF 72 RETROSPOT CAKE CASES        24
# 63672    541590     22295           HEART FILIGREE DOVE LARGE        12
# 63673    541590    85231B          CINAMMON SET OF 9 T-LIGHTS        12
#
#            InvoiceDate  UnitPrice  CustomerID         Country    0
# ...

# %%
retail.to_csv('c://bd092_data//absolute)')
